# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step-1 :: Importing the Libraries

# %%
#Importing the libraries 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step-2 :: Loading the dataset.

# %%
data=pd.read_csv("data.csv")
data
# Out:
#                Timestamp  Age  Gender State where you study/work/live  \
# 0    21/07/2021 23:00:10   20  Female                  Andhra Pradesh
# 1    21/07/2021 23:06:42   21    Male                  Andhra Pradesh
# 2    21/07/2021 23:07:16   19    Male                  Andhra Pradesh
# 3    21/07/2021 23:08:02   26  Female                       Telangana
# 4    21/07/2021 23:08:20   21    Male                          Kerala
# ..                   ...  ...     ...                             ...
# 221  01/08/2021 08:10:22   19    Male                  Andhra Pradesh
# 222  01/08/2021 08:10:43   22  Female                             Goa
# 223  01/08/2021 08:11:19   25  Female                     Maharashtra
# 224  01/08/2021 08:11:46   22  Female                  Andhra Pradesh
# 225  01/08/2021 08:25:35   19  Female                  Andhra Pradesh
#
#     Locationwhereyoulive/study/work  \
# 0                     Tier-2 [Town]
# 1                     Tier-1 [City]
# ...

# %% [markdown]
# ### Step-3 :: Preprocessing the dataset.

# %%
# Timestamp column doesnot required for the data analysis so we are removing that column from the dataset.
data=data.drop("Timestamp",axis=1)

# %%
data
# Out:
#      Age  Gender State where you study/work/live  \
# 0     20  Female                  Andhra Pradesh
# 1     21    Male                  Andhra Pradesh
# 2     19    Male                  Andhra Pradesh
# 3     26  Female                       Telangana
# 4     21    Male                          Kerala
# ..   ...     ...                             ...
# 221   19    Male                  Andhra Pradesh
# 222   22  Female                             Goa
# 223   25  Female                     Maharashtra
# 224   22  Female                  Andhra Pradesh
# 225   19  Female                  Andhra Pradesh
#
#     Locationwhereyoulive/study/work  \
# 0                     Tier-2 [Town]
# 1                     Tier-1 [City]
# 2                     Tier-2 [Town]
# 3                     Tier-1 [City]
# 4                  Tier-3 [Village]
# ..                              ...
# 221                   Tier-2 [Town]
# 222                   Tier-1 [City]
# 223                   Tier-2 [Town]
# ...

# %%
# Renaming the columns names to the simpler names for our convience

data=data.rename(columns={"State where you study/work/live":"State","Locationwhereyoulive/study/work":"City",
                     "What kind of products do you prefer to order in online shopping portals?":"Products"})

# %%
data
# Out:
#      Age  Gender           State              City                 Products
# 0     20  Female  Andhra Pradesh     Tier-2 [Town]                 Clothing
# 1     21    Male  Andhra Pradesh     Tier-1 [City]  Electronics and Gadgets
# 2     19    Male  Andhra Pradesh     Tier-2 [Town]                Foot wear
# 3     26  Female       Telangana     Tier-1 [City]                  Grocery
# 4     21    Male          Kerala  Tier-3 [Village]                Foot wear
# ..   ...     ...             ...               ...                      ...
# 221   19    Male  Andhra Pradesh     Tier-2 [Town]                Foot wear
# 222   22  Female             Goa     Tier-1 [City]  Electronics and Gadgets
# 223   25  Female     Maharashtra     Tier-2 [Town]          Beauty Products
# 224   22  Female  Andhra Pradesh     Tier-1 [City]          Beauty Products
# 225   19  Female  Andhra Pradesh     Tier-2 [Town]                 Clothing
#
# [226 rows x 5 columns]

# %%
# To know the first five columns of the dataset.

data.head()
# Out:
#    Age  Gender           State              City                 Products
# 0   20  Female  Andhra Pradesh     Tier-2 [Town]                 Clothing
# 1   21    Male  Andhra Pradesh     Tier-1 [City]  Electronics and Gadgets
# 2   19    Male  Andhra Pradesh     Tier-2 [Town]                Foot wear
# 3   26  Female       Telangana     Tier-1 [City]                  Grocery
# 4   21    Male          Kerala  Tier-3 [Village]                Foot wear

# %%
# To know the columns present in the dataset.

data.columns
# Out:
# Index(['Age', 'Gender', 'State', 'City', 'Products'], dtype='object')

# %%
# Checking the number of columns and rows present in the dataset.

data.shape
# Out:
# (226, 5)

# %%
# Checking if any null values are present in the dataset.

data.isnull().sum()
# Out:
# Age         0
# Gender      0
# State       0
# City        0
# Products    0
# dtype: int64

# %%
# Checking information about the columns of the  dataset such as number of non null values and data type of each column.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       226 non-null    int64
#  1   Gender    226 non-null    object
#  2   State     226 non-null    object
#  3   City      226 non-null    object
#  4   Products  226 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 9.0+ KB

# %%
# We have to convert the categorical data into the numerical data so we are using encoding techinques.
# Using label encoding to convert the "Gender" column into the numerical value.

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Gender"]=le.fit_transform(data["Gender"])
data
# Out:
#      Age  Gender           State              City                 Products
# 0     20       0  Andhra Pradesh     Tier-2 [Town]                 Clothing
# 1     21       1  Andhra Pradesh     Tier-1 [City]  Electronics and Gadgets
# 2     19       1  Andhra Pradesh     Tier-2 [Town]                Foot wear
# 3     26       0       Telangana     Tier-1 [City]                  Grocery
# 4     21       1          Kerala  Tier-3 [Village]                Foot wear
# ..   ...     ...             ...               ...                      ...
# 221   19       1  Andhra Pradesh     Tier-2 [Town]                Foot wear
# 222   22       0             Goa     Tier-1 [City]  Electronics and Gadgets
# 223   25       0     Maharashtra     Tier-2 [Town]          Beauty Products
# 224   22       0  Andhra Pradesh     Tier-1 [City]          Beauty Products
# 225   19       0  Andhra Pradesh     Tier-2 [Town]                 Clothing
#
# [226 rows x 5 columns]

# %%
# Using label encoding to convert the column "state" into the numerical value.

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["State"]=le.fit_transform(data["State"])
data
# Out:
#      Age  Gender  State              City                 Products
# 0     20       0      0     Tier-2 [Town]                 Clothing
# 1     21       1      0     Tier-1 [City]  Electronics and Gadgets
# 2     19       1      0     Tier-2 [Town]                Foot wear
# 3     26       0     18     Tier-1 [City]                  Grocery
# 4     21       1     11  Tier-3 [Village]                Foot wear
# ..   ...     ...    ...               ...                      ...
# 221   19       1      0     Tier-2 [Town]                Foot wear
# 222   22       0      5     Tier-1 [City]  Electronics and Gadgets
# 223   25       0     12     Tier-2 [Town]          Beauty Products
# 224   22       0      0     Tier-1 [City]          Beauty Products
# 225   19       0      0     Tier-2 [Town]                 Clothing
#
# [226 rows x 5 columns]

# %%
# Using label encoding to convert the column "City" into the numerical value.

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["City"]=le.fit_transform(data["City"])
data
# Out:
#      Age  Gender  State  City                 Products
# 0     20       0      0     1                 Clothing
# 1     21       1      0     0  Electronics and Gadgets
# 2     19       1      0     1                Foot wear
# 3     26       0     18     0                  Grocery
# 4     21       1     11     2                Foot wear
# ..   ...     ...    ...   ...                      ...
# 221   19       1      0     1                Foot wear
# 222   22       0      5     0  Electronics and Gadgets
# 223   25       0     12     1          Beauty Products
# 224   22       0      0     0          Beauty Products
# 225   19       0      0     1                 Clothing
#
# [226 rows x 5 columns]

# %%
data.head()
# Out:
#    Age  Gender  State  City                 Products
# 0   20       0      0     1                 Clothing
# 1   21       1      0     0  Electronics and Gadgets
# 2   19       1      0     1                Foot wear
# 3   26       0     18     0                  Grocery
# 4   21       1     11     2                Foot wear

# %%
data["City"].value_counts()
# Out:
# 1    84
# 0    81
# 2    61
# Name: City, dtype: int64

# %%
data.head()
# Out:
#    Age  Gender  State  City                 Products
# 0   20       0      0     1                 Clothing
# 1   21       1      0     0  Electronics and Gadgets
# 2   19       1      0     1                Foot wear
# 3   26       0     18     0                  Grocery
# 4   21       1     11     2                Foot wear

# %%
# Taking the required columns that are necessary as input for building the model and converting those values to array form


changed_input=data.iloc[:,0:4]
X=changed_input.values

# %%
X
# Out:
# array([[20,  0,  0,  1],
#        [21,  1,  0,  0],
#        [19,  1,  0,  1],
#        [26,  0, 18,  0],
#        [21,  1, 11,  2],
#        [20,  1, 11,  2],
#        [28,  1, 18,  0],
#        [22,  1, 19,  2],
#        [25,  1, 10,  1],
#        [20,  1,  0,  1],
#        [20,  0, 20,  0],
#        [21,  0, 21,  1],
#        [20,  0,  3,  1],
#        [19,  1,  4,  0],
#        [20,  1,  0,  1],
#        [26,  1,  0,  1],
#        [21,  1,  4,  1],
#        [21,  1, 11,  0],
#        [21,  1,  4,  1],
#        [21,  1,  0,  1],
#        [19,  1,  0,  0],
#        [20,  1,  3,  1],
#        [20,  1, 14,  0],
#        [20,  1, 14,  2],
#        [20,  1,  4,  1],
#        [22,  0,  0,  1],
#        [31,  0,  0,  0],
#        [20,  1,  0,  1],
#        [20,  1,  5,  1],
#        [20,  0,  0,  1],
#        [30,  1,  0,  2],
#        [19,  1,  0,  2],
#        [34,  1,  4,  2],
#        [18,  1,  0,  0],
#        [31,  0,  0,  0],
#        [21,  0,  0,  0],
#        [20,  0,  0,  2],
# ...

# %%
# Taking the output Column

output=data.iloc[:,4:]

# %%
output
# Out:
#                     Products
# 0                   Clothing
# 1    Electronics and Gadgets
# 2                  Foot wear
# 3                    Grocery
# 4                  Foot wear
# ..                       ...
# 221                Foot wear
# 222  Electronics and Gadgets
# 223          Beauty Products
# 224          Beauty Products
# 225                 Clothing
#
# [226 rows x 1 columns]

# %%
Y=output.values

# %%
Y
# Out:
# array([['Clothing'],
#        ['Electronics and Gadgets'],
#        ['Foot wear'],
#        ['Grocery'],
#        ['Foot wear'],
#        ['Clothing'],
#        ['Furniture'],
#        ['Clothing'],
#        ['Electronics and Gadgets'],
#        ['Foot wear'],
#        ['Grocery'],
#        ['Clothing'],
#        ['Clothing'],
#        ['Grocery'],
#        ['Electronics and Gadgets'],
#        ['Electronics and Gadgets'],
#        ['Clothing'],
#        ['Foot wear'],
#        ['Electronics and Gadgets'],
#        ['Clothing'],
#        ['Beauty Products'],
#        ['Foot wear'],
#        ['Furniture'],
#        ['Clothing'],
#        ['Electronics and Gadgets'],
#        ['Clothing'],
#        ['Clothing'],
#        ['Grocery'],
#        ['Electronics and Gadgets'],
#        ['Clothing'],
#        ['Electronics and Gadgets'],
#        ['Electronics and Gadgets'],
#        ['Grocery'],
#        ['Electronics and Gadgets'],
#        ['Clothing'],
#        ['Clothing'],
# ...

# %% [markdown]
# ### Step-4 :: Splitting the dataset into the train and test dataset.

# %%
# Splitting the dataset into train set and test set.

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.5)

# %%
X_train.shape
# Out:
# (113, 4)

# %%
Y_train.shape
# Out:
# (113, 1)

# %%
X_test.shape
# Out:
# (113, 4)

# %%
Y_test.shape
# Out:
# (113, 1)

# %% [markdown]
# ### Step-4 :: Fitting the model-1(K-Nearest Neighbours)

# %%
# Importing the requried model and evaluation metrics and here we are using "K-Nearest Neighbours" algorithm.

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Finding the best value for k to build the model

acc=[]
for i in range(1,21):
    neigh=KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train,Y_train)
    y_pred=neigh.predict(X_test)
    score=accuracy_score(Y_test,y_pred)
    acc.append(score)

# %%
acc
# Out:
# [0.30973451327433627,
#  0.34513274336283184,
#  0.35398230088495575,
#  0.4336283185840708,
#  0.39823008849557523,
#  0.3893805309734513,
#  0.3805309734513274,
#  0.37168141592920356,
#  0.37168141592920356,
#  0.39823008849557523,
#  0.415929203539823,
#  0.415929203539823,
#  0.3893805309734513,
#  0.3805309734513274,
#  0.37168141592920356,
#  0.37168141592920356,
#  0.37168141592920356,
#  0.3893805309734513,
#  0.3805309734513274,
#  0.3805309734513274]

# %%
print("The best accuracy of the model is {0} with k-value {1}".format(max(acc),acc.index(max(acc))))
# Out:
# The best accuracy of the model is 0.4336283185840708 with k-value 3

# %%
# Creating the object for KNN with K-Value=3

neighbour=KNeighborsClassifier(n_neighbors=3)

# %%
# Fitting the KNN model with k-value=3

neighbour.fit(X_test,Y_test)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
# Predict the y-values

y_pred=neighbour.predict(X_test)

# %%
y_pred
# Out:
# array(['Clothing', 'Clothing', 'Grocery', 'Beauty Products',
#        'Electronics and Gadgets', 'Electronics and Gadgets',
#        'Electronics and Gadgets', 'Foot wear', 'Clothing', 'Clothing',
#        'Clothing', 'Clothing', 'Clothing', 'Clothing',
#        'Electronics and Gadgets', 'Grocery', 'Clothing', 'Clothing',
#        'Clothing', 'Clothing', 'Foot wear', 'Clothing', 'Clothing',
#        'Clothing', 'Grocery', 'Clothing', 'Beauty Products', 'Furniture',
#        'Electronics and Gadgets', 'Clothing', 'Electronics and Gadgets',
#        'Clothing', 'Electronics and Gadgets', 'Clothing', 'Clothing',
#        'Foot wear', 'Clothing', 'Electronics and Gadgets',
#        'Electronics and Gadgets', 'Clothing', 'Clothing', 'Clothing',
#        'Clothing', 'Grocery', 'Clothing', 'Electronics and Gadgets',
#        'Clothing', 'Clothing', 'Electronics and Gadgets',
#        'Electronics and Gadgets', 'Clothing', 'Clothing',
# ...

# %% [markdown]
# ### Step-5 :: Caluculating the accuracy score of the model.

# %%
# Caluculating the accuracy Score

print("Accuracy Score:")
Accuracy_score=accuracy_score(Y_test,neighbour.predict(X_test))
print(Accuracy_score*100)
# Out:
# Accuracy Score:
# 61.94690265486725

# %% [markdown]
# ### Applying the Decision Tree Clasifier Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Fitting the Decision Classifier Model
model=DecisionTreeClassifier(criterion="entropy",max_depth=2)
model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['Clothing', 'Electronics and Gadgets', 'Clothing',
#        'Electronics and Gadgets', 'Electronics and Gadgets', 'Clothing',
#        'Electronics and Gadgets', 'Electronics and Gadgets', 'Clothing',
#        'Electronics and Gadgets', 'Clothing', 'Clothing', 'Clothing',
#        'Clothing', 'Electronics and Gadgets', 'Electronics and Gadgets',
#        'Clothing', 'Clothing', 'Electronics and Gadgets', 'Clothing',
#        'Electronics and Gadgets', 'Electronics and Gadgets', 'Clothing',
#        'Clothing', 'Electronics and Gadgets', 'Clothing', 'Clothing',
#        'Clothing', 'Electronics and Gadgets', 'Clothing',
#        'Electronics and Gadgets', 'Clothing', 'Electronics and Gadgets',
#        'Clothing', 'Electronics and Gadgets', 'Electronics and Gadgets',
#        'Clothing', 'Electronics and Gadgets', 'Electronics and Gadgets',
#        'Electronics and Gadgets', 'Electronics and Gadgets',
#        'Electronics and Gadgets', 'Clothing', 'Clothing', 'Clothing',
# ...

# %% [markdown]
# ### Caluculating the accuracy scores.

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(Y_test,y_pred)
print(score*100)
# Out:
# 53.09734513274337

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# From the above two models I can conclude that I got a higher accuracy with the K-Nearest Neighbours Algorithm with K-Value=3
# Which is 69.2%.
#
# We can use K-Nearest Neighbours Algorithm for the prediction of products based on age,gender and location.
#
# The choosen of products mainly depend upon the age and gender.
